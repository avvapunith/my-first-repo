# %% [markdown]
# Hardware is the physical part of a computer or device that we can see and touch, while software is the set of programs or instructions that tell the hardware what to do. For example, a keyboard is hardware, and Google Chrome or Windows is software. Both are important because a device cannot work properly without either one.
